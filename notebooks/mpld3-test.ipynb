# %%
import numpy as np
import sys
# %matplotlib inline

# %%
sys.path.insert(0, '/home/idb/src/mpld3')
import imp
imp.load_package('mpld3', '/home/idb/src/mpld3')
# Out:
# <module 'mpld3' from '/home/idb/src/mpld3'>

# %%
import mpld3
reload(mpld3)
# Out:
# <module 'mpld3' from '/home/idb/src/mpld3/mpld3/__init__.pyc'>

# %%
mpld3.__version__
# Out:
# '0.3git'

# %%
import mpld3
from mpld3 import plugins
from mpld3.utils import get_id
import collections
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
print reload(mpld3.plugins)
print reload(mpld3.utils)
print reload(mpld3)
# Out:
# <module 'mpld3.plugins' from '/home/idb/virtual-environments/py27-mpld3dev/local/lib/python2.7/site-packages/mpld3-0.3git-py2.7.egg/mpld3/plugins.pyc'>
# <module 'mpld3.utils' from '/home/idb/virtual-environments/py27-mpld3dev/local/lib/python2.7/site-packages/mpld3-0.3git-py2.7.egg/mpld3/utils.pyc'>
# <module 'mpld3' from '/home/idb/virtual-environments/py27-mpld3dev/local/lib/python2.7/site-packages/mpld3-0.3git-py2.7.egg/mpld3/__init__.pyc'>

# %%
N_paths = 5
N_steps = 100

x = np.linspace(0, 10, 100)
y = 0.1 * (np.random.random((N_paths, N_steps)) - 0.5)
y = y.cumsum(1)

fig, ax = plt.subplots()
labels = ["a", "b", "c", "d", "e"]
line_collections = ax.plot(x, y.T, lw=4, alpha=0.2)
interactive_legend = plugins.InteractiveLegendPlugin(line_collections, labels)
plugins.connect(fig, interactive_legend)

mpld3.display()
# Out:
# <style>
#
#     .legend-box {
#       cursor: pointer;
#     }
#
# </style>
#
# <div id="fig_el2622877572880810816493"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("interactive_legend", InteractiveLegend);
#     InteractiveLegend.prototype = Object.create(mpld3.Plugin.prototype);
#     InteractiveLegend.prototype.constructor = InteractiveLegend;
#     InteractiveLegend.prototype.requiredProps = ["element_ids", "labels"];
#     InteractiveLegend.prototype.defaultProps = {"ax":null,
#                                                 "alpha_sel":1.0,
#                                                 "alpha_unsel":0}
#     function InteractiveLegend(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     InteractiveLegend.prototype.draw = function(){
#         var alpha_sel = this.props.alpha_sel;
#         var alpha_unsel = this.props.alpha_unsel;
#
#         var legendItems = new Array();
#         for(var i=0; i<this.props.labels.length; i++){
#             var obj = {};
#             obj.label = this.props.labels[i];
#
#             var element_id = this.props.element_ids[i];
#             mpld3_elements = [];
#             for(var j=0; j<element_id.length; j++){
#                 var mpld3_element = mpld3.get_element(element_id[j], this.fig);
#
#                 // mpld3_element might be null in case of Line2D instances
#                 // for we pass the id for both the line and the markers. Either
#                 // one might not exist on the D3 side
#                 if(mpld3_element){
#                     mpld3_elements.push(mpld3_element);
#                 }
#             }
#
#             obj.mpld3_elements = mpld3_elements;
#             obj.visible = false; // should become be setable from python side
#             legendItems.push(obj);
#         }
#
#         // determine the axes with which this legend is associated
#         var ax = this.props.ax
#         if(!ax){
#             ax = this.fig.axes[0];
#         } else{
#             ax = mpld3.get_element(ax, this.fig);
#         }
#
#         // add a legend group to the canvas of the figure
#         var legend = this.fig.canvas.append("svg:g")
#                                .attr("class", "legend");
#
#         // add the rectangles
#         legend.selectAll("rect")
#                 .data(legendItems)
#              .enter().append("rect")
#                 .attr("height",10)
#                 .attr("width", 25)
#                 .attr("x",ax.width+10+ax.position[0])
#                 .attr("y",function(d,i) {
#                             return ax.position[1]+ i * 25 - 10;})
#                 .attr("stroke", get_color)
#                 .attr("class", "legend-box")
#                 .style("fill", function(d, i) {
#                             return d.visible ? get_color(d) : "white";})
#                 .on("click", click);
#
#         // add the labels
#         legend.selectAll("text")
#                 .data(legendItems)
#             .enter().append("text")
#               .attr("x", function (d) {
#                             return ax.width+10+ax.position[0] + 40;})
#               .attr("y", function(d,i) {
#                             return ax.position[1]+ i * 25;})
#               .text(function(d) { return d.label });
#
#         // specify the action on click
#         function click(d,i){
#             d.visible = !d.visible;
#             d3.select(this)
#               .style("fill",function(d, i) {
#                 return d.visible ? get_color(d) : "white";
#               })
#
#             for(var i=0; i<d.mpld3_elements.length; i++){
#                 var type = d.mpld3_elements[i].constructor.name;
#                 if(type =="mpld3_Line"){
#                     d3.select(d.mpld3_elements[i].path[0][0])
#                         .style("stroke-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel);
#                 } else if((type=="mpld3_PathCollection")||
#                          (type=="mpld3_Markers")){
#                     d3.selectAll(d.mpld3_elements[i].pathsobj[0])
#                         .style("stroke-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel)
#                         .style("fill-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel);
#                 } else{
#                     console.log(type + " not yet supported");
#                 }
#             }
#         };
#
#         // helper function for determining the color of the rectangles
#         function get_color(d){
#             var type = d.mpld3_elements[0].constructor.name;
#             var color = "black";
#             if(type =="mpld3_Line"){
#                 color = d.mpld3_elements[0].props.edgecolor;
#             } else if((type=="mpld3_PathCollection")||
#                       (type=="mpld3_Markers")){
#                 color = d.mpld3_elements[0].props.facecolors[0];
#             } else{
#                 console.log(type + " not yet supported");
#             }
#             return color;
#         };
#     };
#
#        mpld3.draw_figure("fig_el2622877572880810816493", {"axes": [{"xlim": [0.0, 10.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 10.0], "ylim": [-0.40000000000000002, 0.59999999999999998], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 7, "tickvalues": null}], "lines": [{"color": "#4C72B0", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622877572688"}, {"color": "#55A868", "yindex": 2, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622875666000"}, {"color": "#C44E52", "yindex": 3, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622875669200"}, {"color": "#8172B2", "yindex": 4, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622875668368"}, {"color": "#CCB974", "yindex": 5, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622875667664"}], "markers": [], "id": "el2622862397136", "ydomain": [-0.40000000000000002, 0.59999999999999998], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "height": 440.0, "width": 640.0, "plugins": [{"type": "reset"}, {"enabled": false, "button": true, "type": "zoom"}, {"enabled": false, "button": true, "type": "boxzoom"}, {"element_ids": [["el2622877572688", "el2622877572688pts"], ["el2622875666000", "el2622875666000pts"], ["el2622875669200", "el2622875669200pts"], ["el2622875668368", "el2622875668368pts"], ["el2622875667664", "el2622875667664pts"]], "type": "interactive_legend", "labels": ["a", "b", "c", "d", "e"], "alpha_unsel": 0.2, "ax": null, "alpha_sel": 1}], "data": {"data01": [[0.0, 0.042608808632496054, -0.04014942593303305, 0.015167207295541142, 0.0004066632669910697, -0.010847964931085275], [0.10101010101010101, 0.01788673225643639, -0.0272643391168681, -0.02277868507385912, -0.035489318948330593, 0.036086018577228825], [0.20202020202020202, 0.041774680615380456, -0.038935483906386834, -0.002

# %%
N_paths = 5
N_steps = 100

x1 = np.linspace(0, 10, 100)
y = 0.1 * (np.random.random((N_paths, N_steps)) - 0.5)
y1 = y.cumsum(1)

x2 = np.linspace(0, 10, 100)
y = 0.1 * (np.random.random((N_paths, N_steps)) - 0.5)
y2 = y.cumsum(1)

fig, ax = plt.subplots()
labels = ["a", "b",]
l1 = ax.plot(x1, y1.T, lw=4, alpha=0.1, c='b', label='a')
l2 = ax.plot(x2, y2.T, lw=4, alpha=0.2, c='r', label='b')

line_collections = [l1,l2]
plugins.connect(fig, plugins.InteractiveLegendPlugin(line_collections, labels))

mpld3.display()
# Out:
# <style>
#
#     .legend-box {
#       cursor: pointer;
#     }
#
# </style>
#
# <div id="fig_el26228755286562502950990"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("interactive_legend", InteractiveLegend);
#     InteractiveLegend.prototype = Object.create(mpld3.Plugin.prototype);
#     InteractiveLegend.prototype.constructor = InteractiveLegend;
#     InteractiveLegend.prototype.requiredProps = ["element_ids", "labels"];
#     InteractiveLegend.prototype.defaultProps = {"ax":null,
#                                                 "alpha_sel":1.0,
#                                                 "alpha_unsel":0}
#     function InteractiveLegend(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     InteractiveLegend.prototype.draw = function(){
#         var alpha_sel = this.props.alpha_sel;
#         var alpha_unsel = this.props.alpha_unsel;
#
#         var legendItems = new Array();
#         for(var i=0; i<this.props.labels.length; i++){
#             var obj = {};
#             obj.label = this.props.labels[i];
#
#             var element_id = this.props.element_ids[i];
#             mpld3_elements = [];
#             for(var j=0; j<element_id.length; j++){
#                 var mpld3_element = mpld3.get_element(element_id[j], this.fig);
#
#                 // mpld3_element might be null in case of Line2D instances
#                 // for we pass the id for both the line and the markers. Either
#                 // one might not exist on the D3 side
#                 if(mpld3_element){
#                     mpld3_elements.push(mpld3_element);
#                 }
#             }
#
#             obj.mpld3_elements = mpld3_elements;
#             obj.visible = false; // should become be setable from python side
#             legendItems.push(obj);
#         }
#
#         // determine the axes with which this legend is associated
#         var ax = this.props.ax
#         if(!ax){
#             ax = this.fig.axes[0];
#         } else{
#             ax = mpld3.get_element(ax, this.fig);
#         }
#
#         // add a legend group to the canvas of the figure
#         var legend = this.fig.canvas.append("svg:g")
#                                .attr("class", "legend");
#
#         // add the rectangles
#         legend.selectAll("rect")
#                 .data(legendItems)
#              .enter().append("rect")
#                 .attr("height",10)
#                 .attr("width", 25)
#                 .attr("x",ax.width+10+ax.position[0])
#                 .attr("y",function(d,i) {
#                             return ax.position[1]+ i * 25 - 10;})
#                 .attr("stroke", get_color)
#                 .attr("class", "legend-box")
#                 .style("fill", function(d, i) {
#                             return d.visible ? get_color(d) : "white";})
#                 .on("click", click);
#
#         // add the labels
#         legend.selectAll("text")
#                 .data(legendItems)
#             .enter().append("text")
#               .attr("x", function (d) {
#                             return ax.width+10+ax.position[0] + 40;})
#               .attr("y", function(d,i) {
#                             return ax.position[1]+ i * 25;})
#               .text(function(d) { return d.label });
#
#         // specify the action on click
#         function click(d,i){
#             d.visible = !d.visible;
#             d3.select(this)
#               .style("fill",function(d, i) {
#                 return d.visible ? get_color(d) : "white";
#               })
#
#             for(var i=0; i<d.mpld3_elements.length; i++){
#                 var type = d.mpld3_elements[i].constructor.name;
#                 if(type =="mpld3_Line"){
#                     d3.select(d.mpld3_elements[i].path[0][0])
#                         .style("stroke-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel);
#                 } else if((type=="mpld3_PathCollection")||
#                          (type=="mpld3_Markers")){
#                     d3.selectAll(d.mpld3_elements[i].pathsobj[0])
#                         .style("stroke-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel)
#                         .style("fill-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel);
#                 } else{
#                     console.log(type + " not yet supported");
#                 }
#             }
#         };
#
#         // helper function for determining the color of the rectangles
#         function get_color(d){
#             var type = d.mpld3_elements[0].constructor.name;
#             var color = "black";
#             if(type =="mpld3_Line"){
#                 color = d.mpld3_elements[0].props.edgecolor;
#             } else if((type=="mpld3_PathCollection")||
#                       (type=="mpld3_Markers")){
#                 color = d.mpld3_elements[0].props.facecolors[0];
#             } else{
#                 console.log(type + " not yet supported");
#             }
#             return color;
#         };
#     };
#
#        mpld3.draw_figure("fig_el26228755286562502950990", {"axes": [{"xlim": [0.0, 10.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [], "zoomable": true, "images": [], "xdomain": [0.0, 10.0], "ylim": [-0.40000000000000002, 0.5], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 6, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [{"color": "#0000FF", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622872024464"}, {"color": "#0000FF", "yindex": 2, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622877127632"}, {"color": "#0000FF", "yindex": 3, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622876964432"}, {"color": "#0000FF", "yindex": 4, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622876964880"}, {"color": "#0000FF", "yindex": 5, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.1, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622876965328"}, {"color": "#FF0000", "yindex": 6, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622872024272"}, {"color": "#FF0000", "yindex": 7, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622877168592"}, {"color": "#FF0000", "yindex": 8, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622877148624"}, {"color": "#FF0000", "yindex": 9, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622877149072"}, {"color": "#FF0000", "yindex": 10, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622877149520"}], "markers": [], "id": "el2622846843472", "ydomain": [-0.40000000000000002, 0.5], "collections": [], "xscale": "linear", "bbox": [0.125, 0.125, 0.77500000000000002, 0.77500000000000002]}], "he

# %%
import sys
import os
import re
sys.path.append('/media/milou/glob/github/masm-vali/masmvali/')
import assembly
reload(assembly)
import nucmer
reload(nucmer)
import refgenome
reload(refgenome)
import validation
reload(validation)
import metassemble
reload(metassemble)

import utils
reload(utils)

import warnings
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
m_even = metassemble.MetAssemble(
             "/media/milou/glob/projects/masmvali-partdeux/reassembly-filtered-reads/Sample_1ng_even/metassemble/", 
             "/media/milou/glob/projects/masmvali-partdeux/reassembly-filtered-reads/Sample_1ng_even/phylogeny-references.tsv",
             "/media/milou/glob/projects/masmvali-partdeux/reassembly-filtered-reads/Sample_1ng_even/metassemble/reference-stats/ref.stats",
             "/media/milou/glob/projects/masmvali-partdeux/reassembly-filtered-reads/Sample_1ng_even/contigs_to_refs.tsv"
             )

# %%
mpl.rcParams['figure.figsize'] = 12, 8
pths = sorted(np.unique(m_even.avp.velvetnoscafminimus2.contig_metagenome_coverage_purest_single_aln_purity_thresholds["min_purity"]))
#sns.set_style("darkgrid")
sns.set_style("darkgrid")
colors = sns.dark_palette("skyblue", len(pths))
#sns.set()

f, ax = plt.subplots(1, 1)
#m_even.avp.velvetnoscafminimus2.contig_metagenome_coverage_purest_single_aln_purity_thresholds["min_purity"]
line_collections = []
for i, p in enumerate(pths):
    has_purity = np.array(m_even.avp.velvetnoscafminimus2.contig_metagenome_coverage_purest_single_aln_purity_thresholds["min_purity"] == p)
    line_collections.append(ax.plot(m_even.avp.velvetnoscafminimus2.contig_metagenome_coverage_purest_single_aln_purity_thresholds[has_purity]["cut_off"],
            m_even.avp.velvetnoscafminimus2.contig_metagenome_coverage_purest_single_aln_purity_thresholds[has_purity]["metagenome_cov_percentage"],
            linewidth=4, color=colors[i], label=p, alpha=(0.2)))


ax.set_xscale('log')
ax.invert_xaxis()
ax.set_ylim([0,100])
ax.set_xlim([10**6,0])
ax.set_title("minimusvelvetnoscaf31")
f.set_size_inches(12,10)
plugins.connect(f, plugins.InteractiveLegendPlugin(line_collections, pths))
mpld3.display()
# Out:
# <style>
#
#     .legend-box {
#       cursor: pointer;
#     }
#
# </style>
#
# <div id="fig_el26228468930087130265802"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#     mpld3.register_plugin("interactive_legend", InteractiveLegend);
#     InteractiveLegend.prototype = Object.create(mpld3.Plugin.prototype);
#     InteractiveLegend.prototype.constructor = InteractiveLegend;
#     InteractiveLegend.prototype.requiredProps = ["element_ids", "labels"];
#     InteractiveLegend.prototype.defaultProps = {"ax":null,
#                                                 "alpha_sel":1.0,
#                                                 "alpha_unsel":0}
#     function InteractiveLegend(fig, props){
#         mpld3.Plugin.call(this, fig, props);
#     };
#
#     InteractiveLegend.prototype.draw = function(){
#         var alpha_sel = this.props.alpha_sel;
#         var alpha_unsel = this.props.alpha_unsel;
#
#         var legendItems = new Array();
#         for(var i=0; i<this.props.labels.length; i++){
#             var obj = {};
#             obj.label = this.props.labels[i];
#
#             var element_id = this.props.element_ids[i];
#             mpld3_elements = [];
#             for(var j=0; j<element_id.length; j++){
#                 var mpld3_element = mpld3.get_element(element_id[j], this.fig);
#
#                 // mpld3_element might be null in case of Line2D instances
#                 // for we pass the id for both the line and the markers. Either
#                 // one might not exist on the D3 side
#                 if(mpld3_element){
#                     mpld3_elements.push(mpld3_element);
#                 }
#             }
#
#             obj.mpld3_elements = mpld3_elements;
#             obj.visible = false; // should become be setable from python side
#             legendItems.push(obj);
#         }
#
#         // determine the axes with which this legend is associated
#         var ax = this.props.ax
#         if(!ax){
#             ax = this.fig.axes[0];
#         } else{
#             ax = mpld3.get_element(ax, this.fig);
#         }
#
#         // add a legend group to the canvas of the figure
#         var legend = this.fig.canvas.append("svg:g")
#                                .attr("class", "legend");
#
#         // add the rectangles
#         legend.selectAll("rect")
#                 .data(legendItems)
#              .enter().append("rect")
#                 .attr("height",10)
#                 .attr("width", 25)
#                 .attr("x",ax.width+10+ax.position[0])
#                 .attr("y",function(d,i) {
#                             return ax.position[1]+ i * 25 - 10;})
#                 .attr("stroke", get_color)
#                 .attr("class", "legend-box")
#                 .style("fill", function(d, i) {
#                             return d.visible ? get_color(d) : "white";})
#                 .on("click", click);
#
#         // add the labels
#         legend.selectAll("text")
#                 .data(legendItems)
#             .enter().append("text")
#               .attr("x", function (d) {
#                             return ax.width+10+ax.position[0] + 40;})
#               .attr("y", function(d,i) {
#                             return ax.position[1]+ i * 25;})
#               .text(function(d) { return d.label });
#
#         // specify the action on click
#         function click(d,i){
#             d.visible = !d.visible;
#             d3.select(this)
#               .style("fill",function(d, i) {
#                 return d.visible ? get_color(d) : "white";
#               })
#
#             for(var i=0; i<d.mpld3_elements.length; i++){
#                 var type = d.mpld3_elements[i].constructor.name;
#                 if(type =="mpld3_Line"){
#                     d3.select(d.mpld3_elements[i].path[0][0])
#                         .style("stroke-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel);
#                 } else if((type=="mpld3_PathCollection")||
#                          (type=="mpld3_Markers")){
#                     d3.selectAll(d.mpld3_elements[i].pathsobj[0])
#                         .style("stroke-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel)
#                         .style("fill-opacity",
#                                 d.visible ? alpha_sel : alpha_unsel);
#                 } else{
#                     console.log(type + " not yet supported");
#                 }
#             }
#         };
#
#         // helper function for determining the color of the rectangles
#         function get_color(d){
#             var type = d.mpld3_elements[0].constructor.name;
#             var color = "black";
#             if(type =="mpld3_Line"){
#                 color = d.mpld3_elements[0].props.edgecolor;
#             } else if((type=="mpld3_PathCollection")||
#                       (type=="mpld3_Markers")){
#                 color = d.mpld3_elements[0].props.facecolors[0];
#             } else{
#                 console.log(type + " not yet supported");
#             }
#             return color;
#         };
#     };
#
#        mpld3.draw_figure("fig_el26228468930087130265802", {"axes": [{"xlim": [1000000.0, 100.0], "yscale": "linear", "axesbg": "#EAEAF2", "texts": [{"v_baseline": "auto", "h_anchor": "middle", "color": "#262626", "text": "minimusvelvetnoscaf31", "coordinates": "axes", "zorder": 3, "alpha": 1, "fontsize": 12.0, "position": [0.5, 1.0089605734767024], "rotation": -0.0, "id": "el2622846815312"}], "zoomable": true, "images": [], "xdomain": [1000000.0, 100.0], "ylim": [0.0, 100.0], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "log", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 7, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#FFFFFF", "alpha": 1.0, "dasharray": "none", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 6, "tickvalues": null}], "lines": [{"color": "#222222", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622871537424"}, {"color": "#282D2F", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622871540176"}, {"color": "#2F383C", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622871917968"}, {"color": "#36444A", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622871920592"}, {"color": "#3C4F57", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622871921040"}, {"color": "#435B64", "yindex": 1, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622872099984"}, {"color": "#4A6672", "yindex": 2, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622872100368"}, {"color": "#51727F", "yindex": 3, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622884345744"}, {"color": "#577D8D", "yindex": 4, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth": 4, "data": "data01", "id": "el2622884347344"}, {"color": "#5E899A", "yindex": 5, "coordinates": "data", "dasharray": "none", "zorder": 2, "alpha": 0.2, "xindex": 0, "linewidth":
